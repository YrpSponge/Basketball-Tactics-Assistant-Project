# %% [markdown]
# # 4DHumans Demo Notebook
# This a demo notebook for our paper "4DHumans: Reconstructing and Tracking Humans with Transformers".
#
# <p align="left"><img src="https://github.com/shubham-goel/4D-Humans/raw/main/assets/teaser.png" width="800"></p>
#
# <p align="left"><img src="https://github.com/brjathu/PHALP/raw/master/assets/imgs/teaser.gif" width="800"></p>
#
# Project webpage: https://shubham-goel.github.io/4dhumans/
#
# Github repo: https://github.com/shubham-goel/4D-Humans
#
# Instructions:
#
# 1. Enable the GPU Runtime (Runtime > Change Runtime Type > GPU)
# 2. Clone the repository and install depencencies
# 3. Run the demo
# 4. Visualize the video

# %% [markdown]
# # Clone the repository and install dependencies

# %%
# Clone the main repo
# %%capture
! git clone https://github.com/shubham-goel/4D-Humans.git 4D-Humans
# %cd 4D-Humans
# Out:
# UsageError: Line magic function `%%capture` not found.

# %%
# !pip install torch
# !pip install -e .[all]
# Out:
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.8 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 79.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 66.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 52.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.2 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 15.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.6 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 108.1 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Obtaining file:///content/4D-Humans
#   Preparing metadata (setup.py) ... done
# Collecting chumpy@ git+https://github.com/mattloper/chumpy (from hmr2==0.0.0)
#   Cloning https://github.com/mattloper/chumpy to /tmp/pip-install-r06tquaw/chumpy_77e9c75079aa4aa5a576363c50104434
#   Running command git clone --filter=blob:none --quiet https://github.com/mattloper/chumpy /tmp/pip-install-r06tquaw/chumpy_77e9c75079aa4aa5a576363c50104434
#   Resolved https://github.com/mattloper/chumpy to commit 51d5afd92a8ded3637553be8cef41f328a1c863a
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: gdown in /usr/local/lib/python3.11/dist-packages (from hmr2==0.0.0) (5.2.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from hmr2==0.0.0) (2.0.2)
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (from hmr2==0.0.0) (2.6.0+cu124)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.11/dist-packages (from hmr2==0.0.0) (0.21.0+cu124)
# Collecting pytorch-lightning (from hmr2==0.0.0)
#   Downloading pytorch_lightning-2.5.2-py3-none-any.whl.metadata (21 kB)
# Collecting smplx==0.1.28 (from hmr2==0.0.0)
#   Downloading smplx-0.1.28-py3-none-any.whl.metadata (10 kB)
# Collecting pyrender (from hmr2==0.0.0)
#   Downloading pyrender-0.1.45-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.11/dist-packages (from hmr2==0.0.0) (4.11.0.86)
# Collecting yacs (from hmr2==0.0.0)
#   Downloading yacs-0.1.8-py3-none-any.whl.metadata (639 bytes)
# Requirement already satisfied: scikit-image in /usr/local/lib/python3.11/dist-packages (from hmr2==0.0.0) (0.25.2)
# Requirement already satisfied: einops in /usr/local/lib/python3.11/dist-packages (from hmr2==0.0.0) (0.8.1)
# Requirement already satisfied: timm in /usr/local/lib/python3.11/dist-packages (from hmr2==0.0.0) (1.0.16)
# Collecting webdataset (from hmr2==0.0.0)
#   Downloading webdataset-1.0.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: dill in /usr/local/lib/python3.11/dist-packages (from hmr2==0.0.0) (0.3.7)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from hmr2==0.0.0) (2.2.2)
# Collecting detectron2@ git+https://github.com/facebookresearch/detectron2 (from hmr2==0.0.0)
#   Cloning https://github.com/facebookresearch/detectron2 to /tmp/pip-install-r06tquaw/detectron2_4022ba57a9e84950b1e0c120082f5fc2
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2 /tmp/pip-install-r06tquaw/detectron2_4022ba57a9e84950b1e0c120082f5fc2
#   Resolved https://github.com/facebookresearch/detectron2 to commit 0eeec6d5c0ae7e29028c3b976379f70c755209c4
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (2025.3.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch->hmr2==0.0.0) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch->hmr2==0.0.0) (1.3.0)
# Requirement already satisfied: scipy>=0.13.0 in /usr/local/lib/python3.11/dist-packages (from chumpy@ git+https://github.com/mattloper/chumpy->hmr2==0.0.0) (1.15.3)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.11/dist-packages (from chumpy@ git+https://github.com/mattloper/chumpy->hmr2==0.0.0) (1.17.0)
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.11/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (11.2.1)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (3.10.0)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.11/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (2.0.10)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.11/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (3.1.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (3.1.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.11/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (4.67.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.11/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (2.18.0)
# Collecting fvcore<0.1.6,>=0.1.5 (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0)
#   Downloading fvcore-0.1.5.post20221221.tar.gz (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.2/50.2 kB 4.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting iopath<0.1.10,>=0.1.7 (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0)
#   Downloading iopath-0.1.9-py3-none-any.whl.metadata (370 bytes)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in /usr/local/lib/python3.11/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (2.3.0)
# Collecting hydra-core>=1.1 (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0)
#   Downloading hydra_core-1.3.2-py3-none-any.whl.metadata (5.5 kB)
# Collecting black (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0)
#   Downloading black-25.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl.metadata (81 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.3/81.3 kB 8.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (24.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.11/dist-packages (from yacs->hmr2==0.0.0) (6.0.2)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.11/dist-packages (from gdown->hmr2==0.0.0) (4.13.4)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.11/dist-packages (from gdown->hmr2==0.0.0) (2.32.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->hmr2==0.0.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->hmr2==0.0.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->hmr2==0.0.0) (2025.2)
# Collecting freetype-py (from pyrender->hmr2==0.0.0)
#   Downloading freetype_py-2.5.1-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: imageio in /usr/local/lib/python3.11/dist-packages (from pyrender->hmr2==0.0.0) (2.37.0)
# Collecting pyglet>=1.4.10 (from pyrender->hmr2==0.0.0)
#   Downloading pyglet-2.1.6-py3-none-any.whl.metadata (7.7 kB)
# Collecting PyOpenGL==3.1.0 (from pyrender->hmr2==0.0.0)
#   Downloading PyOpenGL-3.1.0.zip (2.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 84.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting trimesh (from pyrender->hmr2==0.0.0)
#   Downloading trimesh-4.6.13-py3-none-any.whl.metadata (18 kB)
# Collecting torchmetrics>=0.7.0 (from pytorch-lightning->hmr2==0.0.0)
#   Downloading torchmetrics-1.7.4-py3-none-any.whl.metadata (21 kB)
# Collecting lightning-utilities>=0.10.0 (from pytorch-lightning->hmr2==0.0.0)
#   Downloading lightning_utilities-0.14.3-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: tifffile>=2022.8.12 in /usr/local/lib/python3.11/dist-packages (from scikit-image->hmr2==0.0.0) (2025.6.11)
# Requirement already satisfied: lazy-loader>=0.4 in /usr/local/lib/python3.11/dist-packages (from scikit-image->hmr2==0.0.0) (0.4)
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.11/dist-packages (from timm->hmr2==0.0.0) (0.33.1)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.11/dist-packages (from timm->hmr2==0.0.0) (0.5.3)
# Collecting braceexpand (from webdataset->hmr2==0.0.0)
#   Downloading braceexpand-0.1.7-py2.py3-none-any.whl.metadata (3.0 kB)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /usr/local/lib/python3.11/dist-packages (from fsspec[http]>=2022.5.0->pytorch-lightning->hmr2==0.0.0) (3.11.15)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.11/dist-packages (from hydra-core>=1.1->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (4.9.3)
# Collecting portalocker (from iopath<0.1.10,>=0.1.7->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0)
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from lightning-utilities>=0.10.0->pytorch-lightning->hmr2==0.0.0) (75.2.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.11/dist-packages (from beautifulsoup4->gdown->hmr2==0.0.0) (2.7)
# Requirement already satisfied: click>=8.0.0 in /usr/local/lib/python3.11/dist-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (8.2.1)
# Collecting mypy-extensions>=0.4.3 (from black->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0)
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl.metadata (1.1 kB)
# Collecting pathspec>=0.9.0 (from black->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0)
#   Downloading pathspec-0.12.1-py3-none-any.whl.metadata (21 kB)
# Requirement already satisfied: platformdirs>=2 in /usr/local/lib/python3.11/dist-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (4.3.8)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from huggingface_hub->timm->hmr2==0.0.0) (1.1.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch->hmr2==0.0.0) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (4.58.4)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (3.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->hmr2==0.0.0) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->hmr2==0.0.0) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->hmr2==0.0.0) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->hmr2==0.0.0) (2025.6.15)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.11/dist-packages (from requests[socks]->gdown->hmr2==0.0.0) (1.7.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (1.73.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (3.8.2)
# Requirement already satisfied: protobuf!=4.24.0,>=3.19.6 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (5.29.5)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2->hmr2==0.0.0) (3.1.3)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->hmr2==0.0.0) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->hmr2==0.0.0) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->hmr2==0.0.0) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->hmr2==0.0.0) (1.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->hmr2==0.0.0) (6.6.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->hmr2==0.0.0) (0.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning->hmr2==0.0.0) (1.20.1)
# Downloading smplx-0.1.28-py3-none-any.whl (29 kB)
# Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Downloading pyrender-0.1.45-py3-none-any.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 76.5 MB/s eta 0:00:00
# Downloading pytorch_lightning-2.5.2-py3-none-any.whl (825 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 825.4/825.4 kB 61.3 MB/s eta 0:00:00
# Downloading webdataset-1.0.2-py3-none-any.whl (74 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 7.9 MB/s eta 0:00:00
# Downloading hydra_core-1.3.2-py3-none-any.whl (154 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.5/154.5 kB 16.7 MB/s eta 0:00:00
# Downloading iopath-0.1.9-py3-none-any.whl (27 kB)
# Downloading lightning_utilities-0.14.3-py3-none-any.whl (28 kB)
# Downloading pyglet-2.1.6-py3-none-any.whl (983 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 984.0/984.0 kB 67.9 MB/s eta 0:00:00
# Downloading torchmetrics-1.7.4-py3-none-any.whl (963 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 963.5/963.5 kB 66.2 MB/s eta 0:00:00
# Downloading black-25.1.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.manylinux_2_28_x86_64.whl (1.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 87.4 MB/s eta 0:00:00
# Downloading braceexpand-0.1.7-py2.py3-none-any.whl (5.9 kB)
# Downloading freetype_py-2.5.1-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 71.9 MB/s eta 0:00:00
# Downloading trimesh-4.6.13-py3-none-any.whl (712 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 712.4/712.4 kB 58.9 MB/s eta 0:00:00
# Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Downloading pathspec-0.12.1-py3-none-any.whl (31 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Building wheels for collected packages: chumpy, detectron2, PyOpenGL, fvcore
#   Building wheel for chumpy (setup.py) ... done
#   Created wheel for chumpy: filename=chumpy-0.71-py3-none-any.whl size=60848 sha256=6c9ef35eb5cceafe60ed780f31462f874acfd924c6215be739c74e2c54ac9ad4
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ai071lr2/wheels/ca/2d/f2/a697ad8b3d5af13eb477a977986306282aef09e0b0624dbd77
#   Building wheel for detectron2 (setup.py) ... done
#   Created wheel for detectron2: filename=detectron2-0.6-cp311-cp311-linux_x86_64.whl size=6434916 sha256=45a89bc11d13a1bc1314ce7c253b8e9c47cd0742d180d3ae12b909afb7229cb8
#   Stored in directory: /tmp/pip-ephem-wheel-cache-ai071lr2/wheels/82/fd/8c/d3f45a18b1ac1b9e8c451858d5f394138eeb3a7c9f3bfc590b
#   Building wheel for PyOpenGL (setup.py) ... done
#   Created wheel for PyOpenGL: filename=PyOpenGL-3.1.0-py3-none-any.whl size=1745193 sha256=58311c7f88875cfd774b04510158e71fc12f7826bcd41d6af8afa5a13bf5eb87
#   Stored in directory: /root/.cache/pip/wheels/2f/37/f5/f88cd3dddf75bc3ce608e44bf8a79078c408bf1f351a50818e
#   Building wheel for fvcore (setup.py) ... done
#   Created wheel for fvcore: filename=fvcore-0.1.5.post20221221-py3-none-any.whl size=61397 sha256=1533621de473e445c891714420c1a8dd7069b63d228d747c20ac3f249d2f5071
#   Stored in directory: /root/.cache/pip/wheels/65/71/95/3b8fde5c65c6e4a806e0867c1651dcc71a1cb2f3430e8f355f
# Successfully built chumpy detectron2 PyOpenGL fvcore
# Installing collected packages: PyOpenGL, braceexpand, yacs, webdataset, trimesh, pyglet, portalocker, pathspec, mypy-extensions, lightning-utilities, freetype-py, pyrender, iopath, hydra-core, chumpy, black, fvcore, torchmetrics, smplx, detectron2, pytorch-lightning, hmr2
#   Attempting uninstall: PyOpenGL
#     Found existing installation: PyOpenGL 3.1.9
#     Uninstalling PyOpenGL-3.1.9:
#       Successfully uninstalled PyOpenGL-3.1.9
#   Running setup.py develop for hmr2
# Successfully installed PyOpenGL-3.1.0 black-25.1.0 braceexpand-0.1.7 chumpy-0.71 detectron2-0.6 freetype-py-2.5.1 fvcore-0.1.5.post20221221 hmr2-0.0.0 hydra-core-1.3.2 iopath-0.1.9 lightning-utilities-0.14.3 mypy-extensions-1.1.0 pathspec-0.12.1 portalocker-3.2.0 pyglet-2.1.6 pyrender-0.1.45 pytorch-lightning-2.5.2 smplx-0.1.28 torchmetrics-1.7.4 trimesh-4.6.13 webdataset-1.0.2 yacs-0.1.8

# %%
# %cd /content/4D-Humans
# !wget https://github.com/classner/up/raw/821a390fbf87a522fb327fc46736eda0326e2a06/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl
# !mkdir data/
# !cp basicModel_neutral_lbs_10_207_0_v1.0.0.pkl ./data/
# Out:
# /content/4D-Humans
# --2025-07-07 06:03:26--  https://github.com/classner/up/raw/821a390fbf87a522fb327fc46736eda0326e2a06/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl
# Resolving github.com (github.com)... 20.205.243.166
# Connecting to github.com (github.com)|20.205.243.166|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/classner/up/821a390fbf87a522fb327fc46736eda0326e2a06/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl [following]
# --2025-07-07 06:03:27--  https://raw.githubusercontent.com/classner/up/821a390fbf87a522fb327fc46736eda0326e2a06/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39001280 (37M) [application/octet-stream]
# Saving to: ‘basicModel_neutral_lbs_10_207_0_v1.0.0.pkl’
#
# basicModel_neutral_ 100%[===================>]  37.19M  --.-KB/s    in 0.09s
#
# 2025-07-07 06:03:32 (401 MB/s) - ‘basicModel_neutral_lbs_10_207_0_v1.0.0.pkl’ saved [39001280/39001280]

# %% [markdown]
# # Run the demo

# %%
# run hmr2 on a folder of images
# !python demo.py \
--img_folder example_data/images \
--out_folder demo_out \
--batch_size=48 --side_view --save_mesh
# Out:
# /usr/local/lib/python3.11/dist-packages/timm/models/layers/__init__.py:48: FutureWarning: Importing from timm.models.layers is deprecated, please import via timm.layers
#   warnings.warn(f"Importing from {__name__} is deprecated, please import via timm.layers", FutureWarning)
# Downloading file: hmr2_data.tar.gz
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/4dhumans/hmr2_data.tar.gz to /root/.cache/4DHumans/hmr2_data.tar.gz
#   [============================================================] 100.0% of 2585.0MB file
# Extracting file: hmr2_data.tar.gz
# data/
# data/smpl/
# data/smpl_mean_params.npz
# data/SMPL_to_J19.pkl
# logs/
# logs/train/
# logs/train/multiruns/
# logs/train/multiruns/hmr2/
# logs/train/multiruns/hmr2/0/
# logs/train/multiruns/hmr2/0/checkpoints/
# logs/train/multiruns/hmr2/0/checkpoints/epoch=35-step=1000000.ckpt
# logs/train/multiruns/hmr2/0/model_config.yaml
# logs/train/multiruns/hmr2/0/dataset_config.yaml
# Traceback (most recent call last):
#   File "/content/4D-Humans/demo.py", line 171, in <module>
#     main()
#   File "/content/4D-Humans/demo.py", line 35, in main
#     model, model_cfg = load_hmr2(args.checkpoint)
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/4D-Humans/hmr2/models/__init__.py", line 82, in load_hmr2
#     check_smpl_exists()
#   File "/content/4D-Humans/hmr2/models/__init__.py", line 43, in check_smpl_exists
#     convert_pkl(candidates[1], candidates[0])
#   File "/content/4D-Humans/hmr2/models/__init__.py", line 61, in convert_pkl
#     loaded = pickle.load(f, encoding="latin1")
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/chumpy/__init__.py", line 1, in <module>
#     from .ch import *
#   File "/usr/local/lib/python3.11/dist-packages/chumpy/ch.py", line 1319, in <module>
#     from . import linalg
#   File "/usr/local/lib/python3.11/dist-packages/chumpy/linalg.py", line 178, in <module>
#     class SvdD(Ch):
#   File "/usr/local/lib/python3.11/dist-packages/chumpy/linalg.py", line 181, in SvdD
#     @depends_on('x')
#      ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/dist-packages/chumpy/ch.py", line 1203, in _depends_on
#     want_out = 'out' in inspect.getargspec(func).args
#                         ^^^^^^^^^^^^^^^^^^
# AttributeError: module 'inspect' has no attribute 'getargspec'. Did you mean: 'getargs'?

# %% [markdown]
# ### Visualize the reconstructions

# %%
from IPython.display import Image, display
import os
# https://colab.research.google.com/drive/1Ex4gE5v1bPR3evfhtG7sDHxQGsWwNwby?usp=sharing
output_images = ["demo_out/" + i for i in os.listdir("demo_out/") if ".png" in i]
for img in output_images:
  display(Image(img))

# %% [markdown]
# # Video Demo

# %% [markdown]
# ### Install PHALP

# %%
# !pip install git+https://github.com/brjathu/PHALP.git
# Out:
# Collecting git+https://github.com/brjathu/PHALP.git
#   Cloning https://github.com/brjathu/PHALP.git to /tmp/pip-req-build-zvjfxz80
#   Running command git clone --filter=blob:none --quiet https://github.com/brjathu/PHALP.git /tmp/pip-req-build-zvjfxz80
#   Resolved https://github.com/brjathu/PHALP.git to commit 6a0ef228714093dc6278df101d97884352210e68
#   Preparing metadata (setup.py) ... done
# Collecting detectron2@ git+https://github.com/facebookresearch/detectron2.git (from phalp==0.1.3)
#   Cloning https://github.com/facebookresearch/detectron2.git to /tmp/pip-install-ajkaz9yh/detectron2_ef30e97bca4f4ffebec67452031019c2
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/detectron2.git /tmp/pip-install-ajkaz9yh/detectron2_ef30e97bca4f4ffebec67452031019c2
#   Resolved https://github.com/facebookresearch/detectron2.git to commit 5de5319a49e7ea819586d3d6a817632392dfdeb2
#   Preparing metadata (setup.py) ... done
# Collecting pytube@ git+https://github.com/pytube/pytube.git (from phalp==0.1.3)
#   Cloning https://github.com/pytube/pytube.git to /tmp/pip-install-ajkaz9yh/pytube_cec37531699e4f85b6e059ac63917805
#   Running command git clone --filter=blob:none --quiet https://github.com/pytube/pytube.git /tmp/pip-install-ajkaz9yh/pytube_cec37531699e4f85b6e059ac63917805
#   Resolved https://github.com/pytube/pytube.git to commit a32fff39058a6f7e5e59ecd06a7467b71197ce35
#   Preparing metadata (setup.py) ... done
# Collecting pyopengl@ git+https://github.com/mmatl/pyopengl.git (from phalp==0.1.3)
#   Cloning https://github.com/mmatl/pyopengl.git to /tmp/pip-install-ajkaz9yh/pyopengl_6a19b63f051c4220aeab13769d0a7133
#   Running command git clone --filter=blob:none --quiet https://github.com/mmatl/pyopengl.git /tmp/pip-install-ajkaz9yh/pyopengl_6a19b63f051c4220aeab13769d0a7133
#   Resolved https://github.com/mmatl/pyopengl.git to commit 76d1261adee2d3fd99b418e75b0416bb7d2865e6
#   Preparing metadata (setup.py) ... done
# Collecting chumpy@ git+https://github.com/mattloper/chumpy (from phalp==0.1.3)
#   Cloning https://github.com/mattloper/chumpy to /tmp/pip-install-ajkaz9yh/chumpy_13e81bbb9db8416b82eac699a5595567
#   Running command git clone --filter=blob:none --quiet https://github.com/mattloper/chumpy /tmp/pip-install-ajkaz9yh/chumpy_13e81bbb9db8416b82eac699a5595567
#   Resolved https://github.com/mattloper/chumpy to commit 51d5afd92a8ded3637553be8cef41f328a1c863a
#   Preparing metadata (setup.py) ... done
# Collecting neural-renderer-pytorch@ git+https://github.com/shubham-goel/NMR.git (from phalp==0.1.3)
#   Cloning https://github.com/shubham-goel/NMR.git to /tmp/pip-install-ajkaz9yh/neural-renderer-pytorch_b95cd0666f3046079f1bd6def863ab0f
#   Running command git clone --filter=blob:none --quiet https://github.com/shubham-goel/NMR.git /tmp/pip-install-ajkaz9yh/neural-renderer-pytorch_b95cd0666f3046079f1bd6def863ab0f
#   Resolved https://github.com/shubham-goel/NMR.git to commit e990b3c70f48d39231f607c79d76ce3db4bf7483
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (4.8.0.76)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (1.3.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (1.2.2)
# Requirement already satisfied: pyrender in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (0.1.45)
# Requirement already satisfied: dill in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (0.3.7)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (13.7.0)
# Requirement already satisfied: einops in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (0.7.0)
# Collecting scenedetect[opencv] (from phalp==0.1.3)
#   Downloading scenedetect-0.6.2-py3-none-any.whl (117 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 117.1/117.1 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: hydra-core in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (1.3.2)
# Requirement already satisfied: timm in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (0.9.12)
# Collecting av (from phalp==0.1.3)
#   Downloading av-11.0.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (32.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 31.0 MB/s eta 0:00:00
# Requirement already satisfied: smplx==0.1.28 in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (0.1.28)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from phalp==0.1.3) (1.23.5)
# Requirement already satisfied: torch>=1.0.1.post2 in /usr/local/lib/python3.10/dist-packages (from smplx==0.1.28->phalp==0.1.3) (2.1.0+cu118)
# Requirement already satisfied: scipy>=0.13.0 in /usr/local/lib/python3.10/dist-packages (from chumpy@ git+https://github.com/mattloper/chumpy->phalp==0.1.3) (1.11.4)
# Requirement already satisfied: six>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from chumpy@ git+https://github.com/mattloper/chumpy->phalp==0.1.3) (1.16.0)
# Requirement already satisfied: Pillow>=7.1 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (9.4.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (3.7.1)
# Requirement already satisfied: pycocotools>=2.0.2 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.0.7)
# Requirement already satisfied: termcolor>=1.1 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.3.0)
# Requirement already satisfied: yacs>=0.1.8 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.1.8)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.9.0)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.2.1)
# Requirement already satisfied: tqdm>4.29.0 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (4.66.1)
# Requirement already satisfied: tensorboard in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.14.1)
# Requirement already satisfied: fvcore<0.1.6,>=0.1.5 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.1.5.post20221221)
# Requirement already satisfied: iopath<0.1.10,>=0.1.7 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.1.9)
# Requirement already satisfied: omegaconf<2.4,>=2.1 in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.3.0)
# Requirement already satisfied: black in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (23.11.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (23.2)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /usr/local/lib/python3.10/dist-packages (from hydra-core->phalp==0.1.3) (4.9.3)
# Requirement already satisfied: freetype-py in /usr/local/lib/python3.10/dist-packages (from pyrender->phalp==0.1.3) (2.4.0)
# Requirement already satisfied: imageio in /usr/local/lib/python3.10/dist-packages (from pyrender->phalp==0.1.3) (2.31.6)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from pyrender->phalp==0.1.3) (3.2.1)
# Requirement already satisfied: pyglet>=1.4.10 in /usr/local/lib/python3.10/dist-packages (from pyrender->phalp==0.1.3) (2.0.10)
# Requirement already satisfied: trimesh in /usr/local/lib/python3.10/dist-packages (from pyrender->phalp==0.1.3) (4.0.5)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->phalp==0.1.3) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich->phalp==0.1.3) (2.16.1)
# Requirement already satisfied: Click in /usr/local/lib/python3.10/dist-packages (from scenedetect[opencv]->phalp==0.1.3) (8.1.7)
# Requirement already satisfied: platformdirs in /usr/local/lib/python3.10/dist-packages (from scenedetect[opencv]->phalp==0.1.3) (4.0.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn->phalp==0.1.3) (3.2.0)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.10/dist-packages (from timm->phalp==0.1.3) (0.16.0+cu118)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (from timm->phalp==0.1.3) (6.0.1)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.10/dist-packages (from timm->phalp==0.1.3) (0.19.4)
# Requirement already satisfied: safetensors in /usr/local/lib/python3.10/dist-packages (from timm->phalp==0.1.3) (0.4.1)
# Requirement already satisfied: portalocker in /usr/local/lib/python3.10/dist-packages (from iopath<0.1.10,>=0.1.7->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.8.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->phalp==0.1.3) (0.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (4.45.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (1.4.5)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.8.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1.post2->smplx==0.1.28->phalp==0.1.3) (3.13.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1.post2->smplx==0.1.28->phalp==0.1.3) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1.post2->smplx==0.1.28->phalp==0.1.3) (1.12)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1.post2->smplx==0.1.28->phalp==0.1.3) (3.1.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1.post2->smplx==0.1.28->phalp==0.1.3) (2023.6.0)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.0.1.post2->smplx==0.1.28->phalp==0.1.3) (2.1.0)
# Requirement already satisfied: mypy-extensions>=0.4.3 in /usr/local/lib/python3.10/dist-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (1.0.0)
# Requirement already satisfied: pathspec>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.11.2)
# Requirement already satisfied: tomli>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from black->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface-hub->timm->phalp==0.1.3) (2.31.0)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (1.4.0)
# Requirement already satisfied: grpcio>=1.48.2 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (1.59.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (3.5.1)
# Requirement already satisfied: protobuf>=3.19.6 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (3.20.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm->phalp==0.1.3) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm->phalp==0.1.3) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm->phalp==0.1.3) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface-hub->timm->phalp==0.1.3) (2023.11.17)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.0.1.post2->smplx==0.1.28->phalp==0.1.3) (1.3.0)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard->detectron2@ git+https://github.com/facebookresearch/detectron2.git->phalp==0.1.3) (3.2.2)
# Building wheels for collected packages: phalp, neural-renderer-pytorch, pytube
#   Building wheel for phalp (setup.py) ... done
#   Created wheel for phalp: filename=phalp-0.1.3-py3-none-any.whl size=68086 sha256=aa9148a4202e87ef5a878bcbad5df6988ac2b25531dd14ff1def45e1cac6ce67
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rtcehzqg/wheels/78/60/a5/1f2ed47d3c8adf5676ba2fda887b106153d50952536ea113a9
#   Building wheel for neural-renderer-pytorch (setup.py) ... done
#   Created wheel for neural-renderer-pytorch: filename=neural_renderer_pytorch-1.1.3-cp310-cp310-linux_x86_64.whl size=7895027 sha256=b566d109a39852569c0469fa9b4921428419be05754e0afef5215a13b1f2ec07
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rtcehzqg/wheels/9f/7a/86/2e98acdc9b54233377868f5cf10ab13383e28d4f1733cdd28f
#   Building wheel for pytube (setup.py) ... done
#   Created wheel for pytube: filename=pytube-15.0.0-py3-none-any.whl size=57579 sha256=f71b889b3e20914c30aaf0997c3e08468f13ff6bca3288f8cb71778e27535adc
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rtcehzqg/wheels/5a/12/87/c8ebc234373bbbfaa9bd27af202f15d1016cfcac72952cc0ec
# Successfully built phalp neural-renderer-pytorch pytube
# Installing collected packages: neural-renderer-pytorch, scenedetect, pytube, av, phalp
# Successfully installed av-11.0.0 neural-renderer-pytorch-1.1.3 phalp-0.1.3 pytube-15.0.0 scenedetect-0.6.2

# %% [markdown]
# ### Track and visualize

# %%
# !python track.py video.source="example_data/videos/gymnasts.mp4" video.start_frame=10 video.end_frame=60
# Out:
# [12/03 09:12:56] INFO     No OpenGL_accelerate module loaded: No module      ]8;id=185527;file:///usr/local/lib/python3.10/dist-packages/OpenGL/acceleratesupport.py\acceleratesupport.py]8;;\:]8;id=753474;file:///usr/local/lib/python3.10/dist-packages/OpenGL/acceleratesupport.py#17\17]8;;\
#                           named 'OpenGL_accelerate'
# --2023-12-03 09:12:58--  https://github.com/classner/up/raw/master/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/classner/up/master/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl [following]
# --2023-12-03 09:12:58--  https://raw.githubusercontent.com/classner/up/master/models/3D/basicModel_neutral_lbs_10_207_0_v1.0.0.pkl
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39001280 (37M) [application/octet-stream]
# Saving to: ‘basicModel_neutral_lbs_10_207_0_v1.0.0.pkl’
#
# basicModel_neutral_ 100%[===================>]  37.19M  --.-KB/s    in 0.1s
#
# 2023-12-03 09:12:59 (282 MB/s) - ‘basicModel_neutral_lbs_10_207_0_v1.0.0.pkl’ saved [39001280/39001280]
#
# Downloading file: head_faces.npy
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/3D/head_faces.npy to /root/.cache/phalp/3D/head_faces.npy
#   [============================================================] 100.0% of 0.0MB file
# Downloading file: mean_std.npy
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/3D/mean_std.npy to /root/.cache/phalp/3D/mean_std.npy
#   [============================================================] 100.0% of 0.0MB file
# Downloading file: smpl_mean_params.npz
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/3D/smpl_mean_params.npz to /root/.cache/phalp/3D/smpl_mean_params.npz
#   [============================================================] 100.0% of 0.0MB file
# Downloading file: SMPL_to_J19.pkl
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/3D/SMPL_to_J19.pkl to /root/.cache/phalp/3D/SMPL_to_J19.pkl
#   [============================================================] 100.0% of 1.0MB file
# Downloading file: texture.npz
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/3D/texture.npz to /root/.cache/phalp/3D/texture.npz
#   [============================================================] 100.0% of 0.6MB file
# Downloading file: bmap_256.npy
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/bmap_256.npy to /root/.cache/phalp/3D/bmap_256.npy
#   [============================================================] 100.0% of 1.5MB file
# Downloading file: fmap_256.npy
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/fmap_256.npy to /root/.cache/phalp/3D/fmap_256.npy
#   [============================================================] 100.0% of 0.3MB file
# Downloading file: hmar_v2_weights.pth
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/weights/hmar_v2_weights.pth to /root/.cache/phalp/weights/hmar_v2_weights.pth
#   [============================================================] 100.0% of 166.5MB file
# Downloading file: pose_predictor.pth
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/weights/pose_predictor_40006.ckpt to /root/.cache/phalp/weights/pose_predictor.pth
#   [============================================================] 100.0% of 139.8MB file
# Downloading file: pose_predictor.yaml
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/weights/config_40006.yaml to /root/.cache/phalp/weights/pose_predictor.yaml
#   [============================================================] 100.0% of 0.0MB file
# Downloading file: ava_labels.pkl
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/ava/ava_labels.pkl to /root/.cache/phalp/ava/ava_labels.pkl
#   [============================================================] 100.0% of 0.0MB file
# Downloading file: ava_class_mapping.pkl
# Downloading remote file https://people.eecs.berkeley.edu/~jathushan/projects/phalp/ava/ava_class_mappping.pkl to /root/.cache/phalp/ava/ava_class_mapping.pkl
#   [============================================================] 100.0% of 0.0MB file
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/hub/checkpoints/resnet50-19c8e357.pth
# 100% 97.8M/97.8M [00:00<00:00, 238MB/s]
# [2023-12-03 09:13:28,876][pytorch_lightning.utilities.migration.utils][INFO] - Lightning automatically upgraded your loaded checkpoint from v1.8.1 to v2.1.2. To apply the upgrade to your files permanently, run `python -m pytorch_lightning.utilities.upgrade_checkpoint ../../root/.cache/4DHumans/logs/train/multiruns/hmr2/0/checkpoints/epoch=35-step=1000000.ckpt`
# WARNING: You are using a SMPL model, with only 10 shape coefficients.
# [2023-12-03 09:13:36,110][phalp.trackers.PHALP][INFO] - Loading Predictor model...
# [2023-12-03 09:13:37,173][phalp.trackers.PHALP][INFO] - Loading Detection model...
# [2023-12-03 09:13:48,661][detectron2.checkpoint.detection_checkpoint][INFO] - [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/ViTDet/COCO/cascade_mask_rcnn_vitdet_h/f328730692/model_final_f05665.pkl ...
# [2023-12-03 09:14:04,073][detectron2.checkpoint.detection_checkpoint][INFO] - [DetectionCheckpointer] Loading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_3x/139653917/model_final_2d9806.pkl ...
# [2023-12-03 09:14:04,075][iopath.common.download][INFO] - Downloading from https://dl.fbaipublicfiles.com/detectron2/COCO-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_3x/139653917/model_final_2d9806.pkl ...
# model_final_2d9806.pkl: 431MB [00:02, 157MB/s]
# [2023-12-03 09:14:06,825][iopath.common.download][INFO] - Successfully downloaded /root/.torch/iopath_cache/detectron2/COCO-InstanceSegmentation/mask_rcnn_X_101_32x8d_FPN_3x/139653917/model_final_2d9806.pkl. 431414189 bytes.
# [2023-12-03 09:14:07,110][phalp.trackers.PHALP][INFO] - Setting up Visualizer...
# [2023-12-03 09:14:08,186][phalp.utils.io][INFO] - Number of frames: 339
# [2023-12-03 09:14:10,648][phalp.trackers.PHALP][INFO] - Setting up DeepSort...
# [2023-12-03 09:14:10,649][phalp.trackers.PHALP][INFO] - Saving tracks at : outputs//results/gymnasts
# Tracking : gymnasts   ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% eta : 0:00:00  time elapsed : 0:03:26

# %%
# Display the reconstruction video
def show_local_mp4_video(file_name, width=640, height=480):
  import io
  import base64
  from IPython.display import HTML
  video_encoded = base64.b64encode(io.open(file_name, 'rb').read())
  return HTML(data='''<video width="{0}" height="{1}" alt="test" controls>
                      <source src="data:video/mp4;base64,{2}" type="video/mp4" />
                      </video>'''.format(width, height, video_encoded.decode('ascii')))

# !ffmpeg -y -hide_banner -loglevel error -i outputs/PHALP_gymnasts.mp4 outputs/PHALP_gymnasts_ffmpeg.mp4
show_local_mp4_video('outputs/PHALP_gymnasts_ffmpeg.mp4', width=960, height=540)
# Out:
# <video width="960" height="540" alt="test" controls>
#                       <source src="data:video/mp4;base64,..." type="video/mp4" />
#                       </video>
